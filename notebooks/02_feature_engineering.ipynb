# %% [markdown]
# # Feature Engineering for Customer Churn Prediction
#
# ## Objective
# The goal of this notebook is to:
# - Transform raw customer data into meaningful features
# - Encode business signals identified during EDA
# - Prepare a clean, model-ready dataset for churn prediction

# %%
# Import Packages
import pandas as pd

# %%
# Load Data
df = pd.read_csv("../data/processed/cleaned_churn_data_jupyter.csv")

# %%
# Check Columns
print(df.columns)
# Out:
# Index(['customer_id', 'gender', 'senior_citizen', 'tenure_months',
#        'contract_type', 'monthly_charges', 'total_charges', 'payment_method',
#        'avg_monthly_usage', 'usage_trend', 'support_tickets_last_3m', 'churn'],
#       dtype='object')

# %%
# Display Data Shape
df.shape
# Out:
# (10000, 12)

# %%
# Display Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              10000 non-null  object
#  1   gender                   10000 non-null  int64
#  2   senior_citizen           10000 non-null  int64
#  3   tenure_months            10000 non-null  int64
#  4   contract_type            10000 non-null  int64
#  5   monthly_charges          10000 non-null  float64
#  6   total_charges            10000 non-null  float64
#  7   payment_method           10000 non-null  int64
#  8   avg_monthly_usage        10000 non-null  float64
#  9   usage_trend              10000 non-null  int64
#  10  support_tickets_last_3m  10000 non-null  int64
#  11  churn                    10000 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 937.6+ KB

# %%
# Display Summary
df.describe()
# Out:
#              gender  senior_citizen  tenure_months  contract_type  \
# count  10000.000000    10000.000000   10000.000000    10000.00000
# mean       0.501300        0.151100      23.474600        0.65230
# std        0.500023        0.358164      16.187037        0.79465
# min        0.000000        0.000000       1.000000        0.00000
# 25%        0.000000        0.000000      11.000000        0.00000
# 50%        1.000000        0.000000      20.000000        0.00000
# 75%        1.000000        0.000000      32.000000        1.00000
# max        1.000000        1.000000      72.000000        2.00000
#
#        monthly_charges  total_charges  payment_method  avg_monthly_usage  \
# count     10000.000000   10000.000000     10000.00000       10000.000000
# mean         70.380092    1649.044038         1.48820         300.023330
# std          24.575732    1341.289226         1.11552         100.354051
# min          20.000000      20.000000         0.00000          50.000000
# 25%          52.897500     684.982500         0.00000         231.800000
# 50%          70.015000    1290.140000         1.00000         301.300000
# 75%          87.252500    2225.522500         2.00000         367.900000
# max         150.000000   10050.000000         3.00000         600.000000
#
#         usage_trend  support_tickets_last_3m         churn
# count  10000.000000             10000.000000  10000.000000
# mean       1.139500                 1.191900      0.317200
# std        0.852826                 1.081384      0.465409
# min        0.000000                 0.000000      0.000000
# 25%        0.000000                 0.000000      0.000000
# 50%        1.000000                 1.000000      0.000000
# 75%        2.000000                 2.000000      1.000000
# max        2.000000                 7.000000      1.000000

# %%
# Display First Five Rows
df.head()
# Out:
#   customer_id  gender  senior_citizen  tenure_months  contract_type  \
# 0      CUST_1       1               0             58              0
# 1      CUST_2       0               0             19              0
# 2      CUST_3       1               1             12              0
# 3      CUST_4       1               0             11              0
# 4      CUST_5       1               1              4              0
#
#    monthly_charges  total_charges  payment_method  avg_monthly_usage  \
# 0            40.63        2356.54               0              335.3
# 1            88.05        1672.95               0              271.9
# 2            44.73         536.76               1              227.8
# 3            84.89         933.79               2              124.0
# 4            82.63         330.52               2              425.4
#
#    usage_trend  support_tickets_last_3m  churn
# 0            2                        1      0
# 1            2                        2      0
# 2            0                        2      0
# 3            2                        3      1
# 4            0                        1      0

# %% [markdown]
# # Data Cleaning

# %%
# Check Null Values
print(df.isnull().sum())
# Out:
# customer_id                0
# gender                     0
# senior_citizen             0
# tenure_months              0
# contract_type              0
# monthly_charges            0
# total_charges              0
# payment_method             0
# avg_monthly_usage          0
# usage_trend                0
# support_tickets_last_3m    0
# churn                      0
# dtype: int64

# %%
# Check NaN Values
print(df.isna().sum())
# Out:
# customer_id                0
# gender                     0
# senior_citizen             0
# tenure_months              0
# contract_type              0
# monthly_charges            0
# total_charges              0
# payment_method             0
# avg_monthly_usage          0
# usage_trend                0
# support_tickets_last_3m    0
# churn                      0
# dtype: int64

# %%
# Check Duplicates
duplicated = df.duplicated()

print(duplicated)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %% [markdown]
# # Feature Engineering

# %%
# Business-Driven Features

# Tenure Bucket
df["tenure_bucket"] = pd.cut(
    df["tenure_months"],
    bins=[0, 12, 36, 72],
    labels=["New", "Mid", "Long"]
)

# %% [markdown]
# **Tenure Bucket**
#
# Customers are segmented into New, Mid, and Long tenure groups.
# New customers are typically more likely to churn.

# %%
# High-Value Customer Flag
df["high_value_customer"] = (df["monthly_charges"] > 90).astype(int)

# %% [markdown]
# **High-Value Customer Flag**
#
# Identifies customers paying premium prices, which helps quantify
# revenue risk associated with churn.

# %%
# Support Intensity Level
df["support_intensity"] = pd.cut(
    df["support_tickets_last_3m"],
    bins=[-1, 1, 3, 10],
    labels=["Low", "Medium", "High"]
)

# %% [markdown]
# **Support Intensity**
#
# Higher support interaction often signals dissatisfaction and churn risk.

# %%
# Encode Categorical Features

# Machine learning models require numeric inputs.

df_encoded = pd.get_dummies(
    df,
    columns=["tenure_bucket", "support_intensity"],
    drop_first=True
)

# %%
# Check And Review
df_encoded.head()
# Out:
#   customer_id  gender  senior_citizen  tenure_months  contract_type  \
# 0      CUST_1       1               0             58              0
# 1      CUST_2       0               0             19              0
# 2      CUST_3       1               1             12              0
# 3      CUST_4       1               0             11              0
# 4      CUST_5       1               1              4              0
#
#    monthly_charges  total_charges  payment_method  avg_monthly_usage  \
# 0            40.63        2356.54               0              335.3
# 1            88.05        1672.95               0              271.9
# 2            44.73         536.76               1              227.8
# 3            84.89         933.79               2              124.0
# 4            82.63         330.52               2              425.4
#
#    usage_trend  support_tickets_last_3m  churn  high_value_customer  \
# 0            2                        1      0                    0
# 1            2                        2      0                    0
# 2            0                        2      0                    0
# 3            2                        3      1                    0
# 4            0                        1      0                    0
#
#    tenure_bucket_Mid  tenure_bucket_Long  support_intensity_Medium  \
# 0              False                True                     False
# 1               True               False                      True
# 2              False               False                      True
# 3              False               False                      True
# 4              False               False                     False
#
#    support_intensity_High
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False

# %%
# Final Feature Review
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               10000 non-null  object
#  1   gender                    10000 non-null  int64
#  2   senior_citizen            10000 non-null  int64
#  3   tenure_months             10000 non-null  int64
#  4   contract_type             10000 non-null  int64
#  5   monthly_charges           10000 non-null  float64
#  6   total_charges             10000 non-null  float64
#  7   payment_method            10000 non-null  int64
#  8   avg_monthly_usage         10000 non-null  float64
#  9   usage_trend               10000 non-null  int64
#  10  support_tickets_last_3m   10000 non-null  int64
#  11  churn                     10000 non-null  int64
#  12  high_value_customer       10000 non-null  int64
#  13  tenure_bucket_Mid         10000 non-null  bool
#  14  tenure_bucket_Long        10000 non-null  bool
#  15  support_intensity_Medium  10000 non-null  bool
#  16  support_intensity_High    10000 non-null  bool
# dtypes: bool(4), float64(3), int64(9), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# The dataset now contains only numerical and one-hot encoded features,
# making it suitable for machine learning models.

# %%
# Save Feature-Engineered Dataset
df_encoded.to_csv(
    "../data/processed/feature_engineered_churn_jupyter.csv",
    index=False
)

# %% [markdown]
# ## Feature Engineering Summary
#
# - Converted tenure into categorical buckets to capture lifecycle effects
# - Created a high-value customer indicator to quantify revenue risk
# - Grouped support interactions to represent customer friction
# - Applied one-hot encoding to prepare features for modeling
#
# These features reflect real-world churn drivers identified during EDA.
